# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline 
# %reload_ext autoreload
# %autoreload

# %% [markdown]
# # Import Data

# %%
print(sns.get_dataset_names())  # Suggest build in dataset
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('car_crashes')
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df2 = sns.load_dataset('tips')
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# ## Distribution Plot

# %%
sns.distplot(df['not_distracted'])
# Out:
# C:\Users\Maruf\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted', ylabel='Density'>

# %%
sns.distplot(df['not_distracted'], kde=False)  # KDE: Kernel Density Estimation, which is false
# Out:
# C:\Users\Maruf\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted'>

# %%
sns.distplot(df['not_distracted'], kde=False, bins=25)
# Out:
# <AxesSubplot:xlabel='not_distracted'>

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(x='speeding', y='alcohol', data=df)

# %%
sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg') # adding regression line

# %%
sns.jointplot(x='speeding', y='alcohol', data=df, kind='kde') # adding kde

# %%
sns.jointplot(x='speeding', y='alcohol', data=df, kind='hex') # adding hexagoan distribution

# %% [markdown]
# ## KDE Plot

# %%
sns.kdeplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df2, hue='sex', palette='Blues')

# %% [markdown]
# # Rug Plot

# %%
sns.rugplot(df2['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# # Styling

# %%
sns.set_style('white')  # style white / darkgrid

plt.figure(figsize=(10,6))

sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')

# %%
sns.set_style('darkgrid')  # style white / darkgrid

plt.figure(figsize=(10,6))

sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')
plt.show()

# %%
sns.set_style('whitegrid')  # Style

plt.figure(figsize=(10,6))

sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')
plt.show()

# %%
sns.set_style('dark')  # style 

plt.figure(figsize=(10,6))

sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')
plt.show()

# %%
sns.set_style('ticks')  # style
plt.figure(figsize=(8,6))
sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')
plt.show()

# %%
sns.set_style('ticks')
plt.figure(figsize=(10,8))
sns.set_context('paper', font_scale=1.6)  # axis text customization: available font: paper, talk & poster
sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')

plt.show()

# %%
sns.set_style('ticks')
plt.figure(figsize=(10,8))
sns.set_context('talk', font_scale=1.4)  
sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.set_context('poster', font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')
plt.show()
# Out:
# C:\Users\Maruf\anaconda3\lib\site-packages\seaborn\axisgrid.py:1740: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
sns.set_style('white')
plt.figure(figsize=(10,8))
sns.set_context('paper', font_scale= 1.4)
sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')
sns.despine(left=True)  # Remove/ Despine left axis line

# %%
sns.set_style('white')
plt.figure(figsize=(10,8))
sns.set_context('paper', font_scale= 1.4)
sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')
sns.despine(left=False)  # Showing left axis line

# %%
sns.set_style('white')
plt.figure(figsize=(10,8))
sns.set_context('paper', font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')
sns.despine(left=True, bottom=True)  # bollom axis line off

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# ## Bar Plot

# %%
 sns.barplot(x='sex', y='total_bill', data=df2)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=df2, estimator=np.median) # base of median
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=df2, estimator=np.std) # Base of std
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=df2, estimator=np.var) # Base of variance
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=df2, estimator=np.cov) # Base of covariance
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x='sex', data=df2)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# sns.countplot(x='sex', y='smoker', data=df2)  # will gives error, takes only sigle categorical values

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x='day', y='total_bill', data=df2, hue='sex')
plt.legend(loc=0)

# %% [markdown]
# # Violin Plot

# %% [markdown]
# - Violin plot is the combination of box & kde plot

# %%
sns.violinplot(x='day', y='total_bill', data=df2, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=df2, hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
