# %% [markdown]
# # Seaborn

# %% [markdown]
# - Ref: 1013

# %% [markdown]
# - https://www.python-graph-gallery.com/scatter-plot/
# - https://www.linkedin.com/in/maruf-hossain-682213150/
# - https://github.com/Maruf2309

# %% [markdown]
# - A scatter plot displays the relationship between 2 numeric variables. Each data point is represented as a circle. Several tools allow to build one in python, this section provides code samples for Seaborn, Matplotlib and Plotly for interactive versions. Note that this online course has a chapter dedicated to scatterplots.

# %%
# Library & Dataset
import seaborn as sns
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Use function regplot to make scatterplot

sns.regplot(x=df['sepal_length'], y=df['sepal_width'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # Scatterplot & Overplotting

# %%
# Libraries
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Dataset
df = pd.DataFrame({'x':np.random.normal(10, 1.2, 20000), 'y':np.random.normal(10, 1.2, 20000), 'group':np.repeat('A', 20000)})
tem1 = pd.DataFrame({'x':np.random.normal(14.5, 1.2, 20000), 'y':np.random.normal(14.5, 1.2, 20000), 'group':np.repeat('B', 20000)})
tem2 = pd.DataFrame({'x': np.random.normal(9.5, 1.5, 20000), 'y':np.random.normal(15.5, 1.5, 20000), 'group':np.repeat('C', 20000)})

df=df.append(tem1).append(tem2)

# Plot
plt.plot('x', 'y', "", data=df, linestyle='', marker='o')   # Marker size important for overplotting
plt.xlabel('Value of X')
plt.ylabel('Value of Y')
plt.title('Overlapping Plot looks like this:', loc='left')   # Default title position Center, can be customized by loc
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\1944069904.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(tem1).append(tem2)
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\1944069904.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot('x', 'y', "", data=df, linestyle='', marker='o')
# Text(0.0, 1.0, 'Overlapping Plot looks like this:')

# %% [markdown]
# # How to Avoid Overlapping

# %% [markdown]
# ## Dot Size

# %% [markdown]
# - Dot Size
# - Decrease Marker size in plot, this way they dont overlap & plot will be clearer

# %%
# Libraries
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Dataset
df = pd.DataFrame({'x':np.random.normal(10, 1.2, 20000), 'y':np.random.normal(10, 1.2, 20000), 'group':np.repeat('A', 20000)})
tem1 = pd.DataFrame({'x': np.random.normal(14.5, 1.2, 20000), 'y':np.random.normal(14.5, 1.2, 20000), 'group':np.repeat('B', 20000)})
tem2 = pd.DataFrame({'x': np.random.normal(9.5, 1.5, 20000), 'y': np.random.normal(15.5, 1.5, 20000), 'group': np.repeat('C', 20000)})

df = df.append(tem1).append(tem2)

# Plot with small marker size
plt.plot ('x', 'y', "", data=df, linestyle='', marker='o', markersize=0.7)
plt.xlabel('Value of X')
plt.ylabel('Value of Y')
plt.title('Overlapping? Try to Reduce Dot Size', loc='left')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\1110880639.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tem1).append(tem2)
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\1110880639.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot ('x', 'y', "", data=df, linestyle='', marker='o', markersize=0.7)

# %% [markdown]
# ## Transperancy

# %% [markdown]
# - We can change the transperancy with Alpha Patermeter

# %%
# Plot with Transperancy

plt.plot('x', 'y', "", data=df, linestyle='', marker='o', markersize=2, alpha=0.05, color='purple')
plt.xlabel('Value of X')
plt.ylabel('Value of Y')
plt.title('Overploting? Try to use transperancy', loc='left')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\1759634369.py:3: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot('x', 'y', "", data=df, linestyle='', marker='o', markersize=2, alpha=0.05, color='purple')

# %% [markdown]
# ## 2D Density

# %% [markdown]
# - Density graph is a good alternative for an overplotted scatterplot. You can see the relationships between the variables better

# %%
# 2D Density Plot
sns.kdeplot(data=df, x="x", y="y", cmap='Reds', shade=True)
plt.title('Overplotting? 2D Density Graph')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\3317874157.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x="x", y="y", cmap='Reds', shade=True)

# %% [markdown]
# ## Sampling

# %% [markdown]
# - Another alternavite solution is to decrease the number of observations. You can use the sample() function of pandas library to select a random sample of items

# %%
# Sample 1000 random lines
df_sample = df.sample(1000)  # it will take 1000 random line from dataset

# Make the plot with this subset
plt.plot( 'x', 'y', "", data=df_sample, linestyle='', marker='^')

# Title
plt.xlabel('Value of X')
plt.ylabel('Value of Y')
plt.title('Overplotting? Sample your data', loc='left')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\1408616196.py:5: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot( 'x', 'y', "", data=df_sample, linestyle='', marker='^')
# Text(0.0, 1.0, 'Overplotting? Sample your data')

# %% [markdown]
# ## Filtering

# %% [markdown]
# - You can filter the data by groups and label a specific group that you want to highlight with coloring it differently

# %%
# Filter the Data Randomly
df_filtered = df[df['group']=='A']

# Plot the whole dataset
plt.plot('x', 'y', "", data=df, linestyle='', marker='o', markersize=1.3, alpha=0.3, label='other group')

# Adding group for Study
plt.plot('x', 'y', "", data=df_filtered, linestyle='', marker='o', markersize=1.3, alpha=0.3, label='group A')

# Adding Title & Legend
plt.legend(markerscale=8)
plt.xlabel('Value of X')
plt.ylabel('Value of Y')
plt.title('Overplotting? Show a specific Group', loc='left')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\2541678758.py:5: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot('x', 'y', "", data=df, linestyle='', marker='o', markersize=1.3, alpha=0.3, label='other group')
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\2541678758.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot('x', 'y', "", data=df_filtered, linestyle='', marker='o', markersize=1.3, alpha=0.3, label='group A')

# %% [markdown]
# ## Grouping

# %% [markdown]
# - We can easily show different groups of your data points by using the lmplot() function of the seaborn and passing the hue parameter to the function.

# %%
# Plot
sns.lmplot(x='x', y='y', data=df, fit_reg=False, hue='group', legend=False, palette="Accent", scatter_kws={"alpha":0.1, "s":15})

# Legend                                                 # Defining legend explictely
plt.legend(loc='lower right', markerscale=2)


# Title
plt.xlabel('Value of X')
plt.ylabel('Value of Y')
plt.title('Overplotting ? Show putative structure', loc='left')
plt.show()

# Palette: (Spectral,Accent, flare,Set2, pastel, husl, pastel6 )

# %% [markdown]
# ## Faceting

# %% [markdown]
# - Faceting is one of the methods you can use to avoid overlapping. Seaborn has a function FacetGrid() for faceting. Note that you can see this post for more information.
# - FaceGrid()

# %%
# Use seaborn for easy faceting
g = sns.FacetGrid(df, col="group", hue="group")
g = (g.map(plt.scatter,"x", "y", edgecolor='w'))  # edgecolor w = white
# Out:
# c:\python310\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# c:\python310\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# c:\python310\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %% [markdown]
# ## Jitter

# %%
# Dataset
a = np.concatenate([np.random.normal(2, 4, 1000), np.random.normal(4, 4, 1000), np.random.normal(1, 2, 500), np.random.normal(10, 2, 500), np.random.normal(8, 4, 1000), np.random.normal(10, 4, 1000)])
df = pd.DataFrame({'x':np.repeat(range(1,6), 1000), 'y':a})

# plot
plt.plot('x', 'y', '', data=df, linestyle='', marker='o')
plt.show()

# A scatterplot with Jitter
sns.stripplot(data=df, x='x', y='y',  jitter=0.2, size=2)
plt.title('Overplotting? Use Jitter when x data are not really continuous', loc='left')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\1247147509.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot('x', 'y', '', data=df, linestyle='', marker='o')

# %% [markdown]
# ## 3D

# %% [markdown]
# - Sometimes it might be useful to use 3D graphs instead of 2D graphs in order to see distributions more clearly. The following code produces a 3D plot using the scipy library

# %%
# libraries
from scipy.stats import kde
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Evaluate a gaussian kde on a regular grid of nbins x nbins over data extents
nbins =300
k = kde.gaussian_kde([df.x, df.y])
xi, yi = np.mgrid[df.x.min():df.x.max():nbins*1j, df.y.min():df.y.max():nbins*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

# Transform it in a dataframe
data=pd.DataFrame({'x':xi.flatten(), 'y':yi.flatten(), 'z':zi})

# Make the Plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_trisurf(data.x, data.y, data.z, cmap=plt.cm.Spectral, linewidth=0.2)

# Adapt angle, first number is up/down, second number is right/left
ax.view_init(30, 80)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\3920991420.py:3: DeprecationWarning: Please use `gaussian_kde` from the `scipy.stats` namespace, the `scipy.stats.kde` namespace is deprecated.
#   k = kde.gaussian_kde([df.x, df.y])
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\3920991420.py:12: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# ## Marginal Distribution

# %% [markdown]
# - Lastly, you can draw a marginal plot using seaborn in order to aviod overlapping in your graph

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# Dataset:
df=pd.DataFrame({'x': np.random.normal(10, 1.2, 20000), 'y': np.random.normal(10, 1.2, 20000), 'group': np.repeat('A',20000) })
tmp1=pd.DataFrame({'x': np.random.normal(14.5, 1.2, 20000), 'y': np.random.normal(14.5, 1.2, 20000), 'group': np.repeat('B',20000) })
tmp2=pd.DataFrame({'x': np.random.normal(9.5, 1.5, 20000), 'y': np.random.normal(15.5, 1.5, 20000), 'group': np.repeat('C',20000) })
df=df.append(tmp1).append(tmp2)

# 2D density + marginal distribution:
sns.jointplot(x=df.x, y=df.y, cmap="Blues", shade=True, kind='kde')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25672\2864168204.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(tmp1).append(tmp2)
# c:\python310\lib\site-packages\seaborn\axisgrid.py:1826: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)
