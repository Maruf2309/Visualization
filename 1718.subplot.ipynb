# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Dataset
df = pd.read_csv('telco_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# sns.countplot('partner', hue = 'Churn', data=df) -->this code sometimes may error then use the code mentioned a
# sns.countplot(x='Partner', hue='Churn', data=df) --> use this when 1st one is type error

# %%
# Suplot
plt.subplot(1,2,1)        # plot number 1
sns.countplot(x='Partner', hue='Churn', data=df)       # Pass the target in hue  

plt.subplot(1,2,2)       # Plot number 2         # row & col is constant, since  I want to see side by side
sns.countplot(x='Dependents', hue='Churn', data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
# Suplot
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)        # plot number 1
sns.countplot(x='Partner', hue='Churn', data=df)       # Pass the target in hue  

plt.subplot(1,2,2)       # Plot number 2         # row & col is constant, since  I want to see side by side
sns.countplot(x='Dependents', hue='Churn', data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %% [markdown]
# # Subplot by Loop

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Finding Feature List - Only Category
feature = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']                                                # remove "tenure" becuse its continuous variable, Keep only categorical variable

# Write a fun that is enumerate

# %% [markdown]
# ### Enumerate

# %% [markdown]
# - It will return tuble with index number & relative col name
# - Find tolal 16 columns from 0 to 15
# - It will be helpful for doing the iteration

# %%
enumerate(feature)

# %%
list(enumerate(feature))
# Out:
# [(0, 'gender'),
#  (1, 'SeniorCitizen'),
#  (2, 'Partner'),
#  (3, 'Dependents'),
#  (4, 'PhoneService'),
#  (5, 'MultipleLines'),
#  (6, 'InternetService'),
#  (7, 'OnlineSecurity'),
#  (8, 'OnlineBackup'),
#  (9, 'DeviceProtection'),
#  (10, 'TechSupport'),
#  (11, 'StreamingTV'),
#  (12, 'StreamingMovies'),
#  (13, 'Contract'),
#  (14, 'PaperlessBilling'),
#  (15, 'PaymentMethod')]

# %% [markdown]
# ### 6 rows & 3 columns

# %%
for i in enumerate(feature):
    plt.subplot(6,3,i[0]+1)
    sns.countplot(x=i[1], hue='Churn', data=df)             # x=i[1], i= 0 & values like features, parter , contact ect

# %%
plt.figure(figsize=(15, 25))
for i in enumerate(feature):
    plt.subplot(6,3,i[0]+1)
    sns.countplot(x=i[1], hue='Churn', data=df)

# %% [markdown]
# ### 4 Rows & 4 Columns

# %%
plt.figure(figsize=(15, 15))
for i in enumerate(feature):
    plt.subplot(4,4,i[0]+1)
    sns.countplot(x=i[1], hue='Churn', data=df) 
    plt.xticks(rotation=45)    # for removeming overlapping text ratation 45 degree
